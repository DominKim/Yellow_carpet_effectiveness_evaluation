# %%
import numpy as np
import pandas as pd
from selenium.webdriver import Chrome
import time
import sqlite3
from pandas.io import sql
import os
import pandas as pd
import time

# %%
seoul1 = pd.read_csv('./data/서울특별시 강북구 옐로카펫 설치현황_20200807.csv',
                   engine='python', encoding='EUC-KR')
seoul1.shape
display(seoul1.head())

# %%
seoul2 = pd.read_csv('./data/서울특별시 관악구_옐로카펫 설치 현황_20200531.csv',
                   engine='python', encoding='EUC-KR')
seoul2.shape
display(seoul2.head())

# %%
seoul3 = pd.read_csv('./data/서울특별시 도봉구_옐로카펫 설치현황(공유데이터광장)_20200915.csv',
                   engine='python', encoding='EUC-KR')
seoul3.shape
display(seoul3.head())

# %%
pd.concat([seoul1, seoul2, seoul3], axis=1)

# %%
import geocoder
import openpyxl
import time

## 엘셀파일 열기
filename = "address.xlsx"
exelFile = openpyxl.load_workbook(filename)

## 시트 설정
sheet = exelFile.worksheets[0]


## 데이터 가져오기
rowCount = 1
for row in sheet.rows:	

	## geocoder 호출
	g = geocoder.google(row[0].value)

	## 응답 실패 처리
	if g.status == "OVER_QUERY_LIMIT":
		while True:
			print("Fail ===> Try Again")
			time.sleep(2)
			g = geocoder.google(row[0].value)
			if g.status == "OK":
				break

	## cell 설정 [ B1 ~ B* : 위도 / C1 ~ C* : 경도]
	lat_cell = sheet.cell(row = rowCount, column = 2)
	lng_cell = sheet.cell(row = rowCount, column = 3)

	## 위도, 경도 변환
	geo = g.latlng

	## 변환 확인
	print(geo)

	## 데이터 추가
	lat_cell.value = geo[0]
	lng_cell.value = geo[1]
	rowCount = rowCount + 1

## 데이터 저장
exelFile.save("address2.xlsx")
# Out:
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-5c405cc33163> in <module>
#      38
#      39         ## 데이터 추가
# ---> 40         lat_cell.value = geo[0]
#      41         lng_cell.value = geo[1]
#      42         rowCount = rowCount + 1
#
# TypeError: 'NoneType' object is not subscriptable

# %%
import urllib
import json

location = "서울특별시 강북구 오현로 9"
data = urllib.request.urlopen("http://maps.googleapis.com/maps/api/geocode/json?sensor=false&language=ko&address=" + location)
json = json.loads(data.read())

latitude = json["results"][0]["geometry"]["location"]["lat"]
longitude = json["results"][0]["geometry"]["location"]["lng"]

print(latitude)
print(longitude)
# Out:
# ---------------------------------------------------------------------------
# InvalidURL                                Traceback (most recent call last)
# <ipython-input-33-cae11e07aa68> in <module>
#       3
#       4 location = "서울특별시 강북구 오현로 9"
# ----> 5 data = urllib.request.urlopen("http://maps.googleapis.com/maps/api/geocode/json?sensor=false&language=ko&address=" + location)
#       6 json = json.loads(data.read())
#       7
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
# ...

# %%
urllib.request.urlopen()

# %%
gu = pd.read_csv('./data/서울특별시 구별 옐로카펫 설치현황_종합.csv',
                   engine='python', encoding='EUC-KR')
gu.shape
display(gu.head())
# Out:
#    연번      위치                   주소 설치년도(월일)   비고  설치개소
# 0   1  송중초등학교      서울특별시 강북구 오현로 9     2017  정문앞   2.0
# 1   2  번동초등학교    서울특별시 강북구 오현로 204     2018  정문앞   1.0
# 2   3  미양초등학교    서울특별시 강북구 솔샘로 195     2018  후문앞   1.0
# 3   4  인수초등학교   서울특별시 강북구 인수봉로 269     2018  정문앞   1.0
# 4   5  우이초등학교  서울특별시 강북구 삼양로99길 36     2019  후문앞   1.0

# %%
a = gu['주소'].str.split()
b = []
for i in range(205):
    b.append(a[i][1])

# %%
c = set(b)

# %%
c = [,강동구,,강서구,,,,금천구,노원구,

,,,,,서초구,,성북구,,

,,용산구,,종로구,중구,]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-ebcbc173865a> in <module>
# ----> 1 c = [강남구,강동구,강북구,강서구,관악구,광진구,구로구,금천구,노원구,
#       2
#       3 도봉구,동대문구,동작구,마포구,서대문구,서초구,성동구,성북구,송파구,
#       4
#       5 양천구,영등포구,용산구,은평구,종로구,중구,중랑구]
#
# NameError: name '강남구' is not defined

# %%
type(c)
# Out:
# set

# %%
# !pip install folium

# %%
import folium

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import requests
from bs4 import BeautifulSoup as bs
from time import sleep
import urllib.request as req

# %%
driver = webdriver.Chrome(
    executable_path="C:/Crawling/chromedriver.exe")
url = "https://map.kakao.com/"

driver.get(url)
sleep(5)

# 지도에 뜨는 창 없애기
driver.find_element_by_css_selector('.layer_body').click()
# 검색창에 검색어 입력하기
search_box = driver.find_element_by_css_selector('#search\.keyword\.query')
search_box.send_keys("비건베이커리")
# 검색버튼 누르기
driver.find_element_by_id('search.keyword.submit').click()

address = driver.find_element_by_xpath('//*[@id="info.search.place.list"]/li[1]/div[5]/div[2]')
# //*[@id="info.search.place.list"]/li[1]/div[5]/div[2]/p[1]
# find_element_by_class_name

# res = req.urlopen(url)
# soup = bs(res, 'html.parser')
# address = soup.select_one('div.info_item > div.addr > p').string
print(address.text.split("\n")[0])
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-28-1ec23fa263a6> in <module>
#      14 driver.find_element_by_id('search.keyword.submit').click()
#      15
# ---> 16 address = driver.find_element_by_xpath('//*[@id="info.search.place.list"]/li[1]/div[5]/div[2]')
#      17 # //*[@id="info.search.place.list"]/li[1]/div[5]/div[2]/p[1]
#      18 # find_element_by_class_name
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
# ...

# %%
address = driver.find_element_by_xpath('//*[@id="info.search.place.list"]/li[1]/div[5]/div[2]')
# //*[@id="info.search.place.list"]/li[1]/div[5]/div[2]

# %%
print(address.text.split("\n")[0])
# Out:
# 서울 마포구 동교로19길 101 1층

# %%
driver.find
# Out:
# <!DOCTYPE html>
#
# <html class="index" lang="ko">
# <head>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=1024" name="viewport"/>
# <link href="//t1.daumcdn.net/kakaomapweb/map/202009111416893/app_A.css" rel="stylesheet"/>
# <link href="//t1.daumcdn.net/kakaomapweb/map/202009111416893/app_B.css" rel="stylesheet"/>
# <link href="//t1.daumcdn.net/kakaomapweb/map/202009111416893/app_C.css" rel="stylesheet"/>
# <link href="//t1.daumcdn.net/kakaomapweb/map/202009111416893/app_D.css" rel="stylesheet"/>
# <link href="//t1.daumcdn.net/kakaomapweb/map/202009111416893/canvas_roadview.css" rel="stylesheet"/>
# <link href="https://t1.daumcdn.net/kakaomapweb/subway/linemap/canvas/prod/css/subway.css" rel="stylesheet"/>
# <link href="/favicon.ico" rel="icon" type="image/x-icon">
# <title>카카오맵</title>
# <script type="text/javascript">
# document.domain = location.host.indexOf('kakao.com') != -1 ? 'kakao.com' : 'daum.net';
#
# ...
