# %%
import pandas as pd
import numpy as np
import re

# %%
str(df2018.loc[0, "발생년월일"])[0:6]
# Out:
# '201812'

# %%
df = pd.read_csv("./qgis_data/cctv_어린이보호구역.csv", encoding = "euc-kr")
df = df.drop_duplicates(["field_1"])

# %%
df.to_csv("./qgis_data/cctv_child_last.csv", encoding = "euc-kr", index=False)

# %%
df2 = pd.read_csv("./qgis_data/cctv_child_last.csv", encoding = "euc-kr")
df2 = df2.drop_duplicates(["대상시설명"])

# %%
df2.to_csv("./qgis_data/child_last.csv", encoding = "euc-kr", index = False)

# %%
df2018 = pd.read_csv("./qgis_data/20200921/2018.csv", encoding = "euc-kr")

# %%
df2018.head(2)
# Out:
#     발생년     발생년월일 주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자 발생지시도  ...      관리기관_1  \
# 0  2018  20181215  야  토     1     1     0     0      0    서울  ...  서울특별시 성북구청
# 1  2018  20181230  야  일     1     1     0     0      0    서울  ...  서울특별시 성북구청
#
#          관할경찰서 CCTV설치여 CCTV설치대 보호구역도      데이터기_1   제공기관_1     제공기관_2  \
# 0  서울특별시 성북경찰서       Y     1.0   NaN  2020/02/28  3070000  서울특별시 성북구
# 1  서울특별시 성북경찰서       Y     1.0   NaN  2020/02/28  3070000  서울특별시 성북구
#
#         옐로카펫_ 보호구역_
# 0           0    95
# 1  2018-04-07    96
#
# [2 rows x 57 columns]

# %%
# df2018.drop_duplicates(["발생년월일", "주야"])

# %%
try:
    for idx in range(len(df2018)):
        a = df[df["소재지도로_2"] == df2018.loc[idx, "소재지도_1"]]
        
        cnt = 0
        for idx2 in range(len(a)):
            if str(df2018.loc[idx, "발생년월일"])[0:6] > a.loc[idx2, "설치년월"]:
                cnt += 1
        if cnt >= 1:
            df2018.loc[idx, "CCTV설치여"] = "Y"
        else:
            df2018.loc[idx, "CCTV설치여"] = "N"
            
except Exception as e:
    print(idx)
# Out:
# 0

# %%
for idx in range(len(df2018)):
    a = df[df["소재지도로_2"] == df2018.loc[idx, "소재지도_1"]].reset_index(drop = True)

    cnt = 0
    for idx2 in range(len(a)):
        if str(df2018.loc[idx, "발생년월일"])[0:6] > str(a.loc[idx2, "설치년월"]):
            cnt += 1
    if cnt >= 1:
        df2018.loc[idx, "CCTV설치여"] = "Y"
        print("yes, 설치여부 = {}".format(df2018.loc[idx, "CCTV설치여"]))
    elif cnt == 0:
        df2018.loc[idx, "CCTV설치여"] = "N"
        print("no, 설치여부 = {}".format(df2018.loc[idx, "CCTV설치여"]))

# %%
df2017 = pd.read_csv("./qgis_data/20200921/2017.csv", encoding = "euc-kr")

for idx in range(len(df2017)):
    a = df[df["소재지도로_2"] == df2017.loc[idx, "소재지도_1"]].reset_index(drop = True)

    cnt = 0
    for idx2 in range(len(a)):
        if str(df2017.loc[idx, "발생년월일"])[0:6] > str(a.loc[idx2, "설치년월"]):
            cnt += 1
    if cnt >= 1:
        df2017.loc[idx, "CCTV설치여"] = "Y"
        print("yes, 설치여부 = {}".format(df2017.loc[idx, "CCTV설치여"]))
    elif cnt == 0:
        df2017.loc[idx, "CCTV설치여"] = "N"
        print("no, 설치여부 = {}".format(df2017.loc[idx, "CCTV설치여"]))

# %%
df2017 = pd.read_csv("./qgis_data/20200921/2017.csv", encoding = "euc-kr")

for idx in range(len(df2017)):
    a = df[df["소재지도로_2"] == df2017.loc[idx, "소재지도_1"]].reset_index(drop = True)

    cnt = 0
    for idx2 in range(len(a)):
        if str(df2017.loc[idx, "발생년월일"])[0:6] > str(a.loc[idx2, "설치년월"]):
            cnt += 1
    if cnt >= 1:
        df2017.loc[idx, "CCTV설치여"] = "Y"
        print("yes, 설치여부 = {}".format(df2017.loc[idx, "CCTV설치여"]))
    elif cnt == 0:
        df2017.loc[idx, "CCTV설치여"] = "N"
        print("no, 설치여부 = {}".format(df2017.loc[idx, "CCTV설치여"]))

# %%
df2016 = pd.read_csv("./qgis_data/20200921/2016.csv", encoding = "euc-kr")

for idx in range(len(df2016)):
    a = df[df["소재지도로_2"] == df2016.loc[idx, "소재지도_1"]].reset_index(drop = True)

    cnt = 0
    for idx2 in range(len(a)):
        if str(df2016.loc[idx, "발생년월일"])[0:6] > str(a.loc[idx2, "설치년월"]):
            cnt += 1
    if cnt >= 1:
        df2016.loc[idx, "CCTV설치여"] = "Y"
        print("yes, 설치여부 = {}".format(df2016.loc[idx, "CCTV설치여"]))
    elif cnt == 0:
        df2016.loc[idx, "CCTV설치여"] = "N"
        print("no, 설치여부 = {}".format(df2016.loc[idx, "CCTV설치여"]))

# %%
df2015 = pd.read_csv("./qgis_data/20200921/2015.csv", encoding = "euc-kr")

for idx in range(len(df2015)):
    a = df[df["소재지도로_2"] == df2015.loc[idx, "소재지도_1"]].reset_index(drop = True)

    cnt = 0
#     print(a)
#     print("사건발생년도 : ",str(df2015.loc[idx, "발생년월일"])[0:6])
    for idx2 in range(len(a)):
        if str(df2015.loc[idx, "발생년월일"])[0:6] > str(a.loc[idx2, "설치년월"]):
#             print(str(a.loc[idx2, "설치년월"]))
            cnt += 1
    if cnt >= 1:
        df2015.loc[idx, "CCTV설치여"] = "Y"
        print("yes, 설치여부 = {}".format(df2015.loc[idx, "CCTV설치여"]))
    elif cnt == 0:
        df2015.loc[idx, "CCTV설치여"] = "N"
        print("no, 설치여부 = {}".format(df2015.loc[idx, "CCTV설치여"]))
# Out:
#    field_1       관리기관명                소재지도로                      소재지지번 설치목적구  \
# 0    14217  서울특별시 양천구청  서울특별시 양천구 남부순환로 698  서울특별시 양천구 신정동 739-13 공원안쪽  생활방범
# 1    14218  서울특별시 양천구청  서울특별시 양천구 남부순환로 698       서울특별시 양천구 신정동 739-13  생활방범
# 2    14278  서울특별시 양천구청  서울특별시 양천구 남부순환로 700       서울특별시 양천구 신정동 739-15  생활방범
#
#    카메라대수  카메라화소 촬영방면정  보관일수    설치년월  ...     관리기관명_2  관할경찰서  CCTV설치여 CCTV설치대  \
# 0      1  200.0  120도  30.0  201512  ...  서울특별시 구로구청  구로경찰서        Y     NaN
# 1      1  200.0  120도  30.0  201412  ...  서울특별시 구로구청  구로경찰서        Y     NaN
# 2      2  200.0  120도  30.0  201512  ...  서울특별시 구로구청  구로경찰서        Y     NaN
#
#    보호구역도     데이터기준_2  제공기관코_2    제공기관명_2 옐로카펫_ 보호구역_
# 0    NaN  2019/10/28  3160000  서울특별시 구로구     0    95
# 1    NaN  2019/10/28  3160000  서울특별시 구로구     0    95
# 2    NaN  2019/10/28  3160000  서울특별시 구로구     0    95
#
# [3 rows x 32 columns]
# 사건발생년도 :  201501
# 201412
#    field_1       관리기관명                소재지도로                      소재지지번 설치목적구  \
# ...

# %%
df2014 = pd.read_csv("./qgis_data/20200921/2014.csv", encoding = "euc-kr")

for idx in range(len(df2014)):
    a = df[df["소재지도로_2"] == df2014.loc[idx, "소재지도_1"]].reset_index(drop = True)

    cnt = 0
    for idx2 in range(len(a)):
        if str(df2014.loc[idx, "발생년월일"])[0:6] > str(a.loc[idx2, "설치년월"]):
            cnt += 1
    if cnt >= 1:
        df2014.loc[idx, "CCTV설치여"] = "Y"
        print("yes, 설치여부 = {}".format(df2014.loc[idx, "CCTV설치여"]))
    elif cnt == 0:
        df2014.loc[idx, "CCTV설치여"] = "N"
        print("no, 설치여부 = {}".format(df2014.loc[idx, "CCTV설치여"]))

# %%
df2013 = pd.read_csv("./qgis_data/20200921/2013.csv", encoding = "euc-kr")

for idx in range(len(df2013)):
    a = df[df["소재지도로_2"] == df2013.loc[idx, "소재지도_1"]].reset_index(drop = True)

    cnt = 0
    for idx2 in range(len(a)):
        if str(df2013.loc[idx, "발생년월일"])[0:6] > str(a.loc[idx2, "설치년월"]):
            cnt += 1
    if cnt >= 1:
        df2013.loc[idx, "CCTV설치여"] = "Y"
        print("yes, 설치여부 = {}".format(df2013.loc[idx, "CCTV설치여"]))
    elif cnt == 0:
        df2013.loc[idx, "CCTV설치여"] = "N"
        print("no, 설치여부 = {}".format(df2013.loc[idx, "CCTV설치여"]))

# %%
df2012 = pd.read_csv("./qgis_data/20200921/2012.csv", encoding = "euc-kr")

for idx in range(len(df2012)):
    a = df[df["소재지도로_2"] == df2012.loc[idx, "소재지도_1"]].reset_index(drop = True)

    cnt = 0
    for idx2 in range(len(a)):
        if str(df2012.loc[idx, "발생년월일"])[0:6] > str(a.loc[idx2, "설치년월"]):
            cnt += 1
    if cnt >= 1:
        df2012.loc[idx, "CCTV설치여"] = "Y"
        print("yes, 설치여부 = {}".format(df2012.loc[idx, "CCTV설치여"]))
    elif cnt == 0:
        df2012.loc[idx, "CCTV설치여"] = "N"
        print("no, 설치여부 = {}".format(df2012.loc[idx, "CCTV설치여"]))

# %%
df2019 = pd.read_csv("./qgis_data/20200921/2019.csv", encoding = "euc-kr")

for idx in range(len(df2019)):
    a = df[df["소재지도로_2"] == df2019.loc[idx, "소재지도_1"]].reset_index(drop = True)

    cnt = 0
    for idx2 in range(len(a)):
        if str(df2019.loc[idx, "발생년월일"])[0:6] > str(a.loc[idx2, "설치년월"]):
            cnt += 1
    if cnt >= 1:
        df2019.loc[idx, "CCTV설치여"] = "Y"
        print("yes, 설치여부 = {}".format(df2019.loc[idx, "CCTV설치여"]))
    elif cnt == 0:
        df2019.loc[idx, "CCTV설치여"] = "N"
        print("no, 설치여부 = {}".format(df2019.loc[idx, "CCTV설치여"]))

# %%
a = pd.concat([df2019, df2018, df2017, df2016, df2015, df2014, df2013, df2012])

# %%
a = a.drop(["가해자_?1", "피해자_?1"], axis = 1)

# %%
a.reset_index(drop = True, inplace = True)
a
# Out:
#       발생년       발생년월일  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자 발생지시도  ...  \
# 0    2019  2019092705   야  금     1     0     0     0      0    서울  ...
# 1    2019  2019022406   주  일     1     0     0     0      0    서울  ...
# 2    2019  2019012303   야  수     1     0     0     0      0    서울  ...
# 3    2019  2019050712   주  화     1     0     0     0      0    서울  ...
# 4    2019  2019050712   주  화     1     0     0     0      0    서울  ...
# ..    ...         ...  .. ..   ...   ...   ...   ...    ...   ...  ...
# 527  2012    20120706  야간  화     1     1     0     0      0    서울  ...
# 528  2012    20120921  야간  토     1     1     0     0      0    서울  ...
# 529  2012    20120921  야간  토     1     1     0     0      0    서울  ...
# 530  2012    20120912  주간  토     2     5     1     2      0    서울  ...
# 531  2012    20120825  야간  수     1     1     0     0      0    서울  ...
#
#           관리기관_1         관할경찰서 CCTV설치여 CCTV설치대 보호구역도      데이터기_1   제공기관_1  \
# ...

# %%
a["옐로카펫_설치유무"] = 0

# %%
for idx in range(len(a)):
    if a.loc[idx, "옐로카펫_"] != "0":
        if str(a.loc[idx, "발생년월일"]) > str(a.loc[idx, "옐로카펫_"]):
            a.loc[idx, "옐로카펫_설치유무"] = 1

# %%
a["옐로카펫_설치유무"].sum()
# Out:
# 23

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 532 entries, 0 to 531
# Data columns (total 60 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   발생년        532 non-null    int64
#  1   발생년월일      532 non-null    int64
#  2   주야         532 non-null    object
#  3   요일         532 non-null    object
#  4   사망자수       532 non-null    int64
#  5   사상자수       532 non-null    int64
#  6   중상자수       532 non-null    int64
#  7   경상자수       532 non-null    int64
#  8   부상신고자      532 non-null    int64
#  9   발생지시도      532 non-null    object
#  10  발생지시군      532 non-null    object
#  11  사고유형_      532 non-null    object
#  12  사고유형__1    532 non-null    object
#  13  사고유형       532 non-null    object
#  14  법규위반       532 non-null    object
#  15  도로형태_      532 non-null    object
#  16  도로형태       532 non-null    object
#  17  가해자_당      532 non-null    object
#  18  피해자_당      525 non-null    object
# ...

# %%
a["평균기온(℃)"] = 0; a["최저기온(℃)"] = 0; a["최고기온(℃)"] = 0; a["강수량(mm)"] = 0

weather = pd.read_csv("./기상정보_20100101-20191231.csv", encoding = "euc-kr")

weather["날짜"] = weather["날짜"].str.replace("-", "")

for idx in range(len(a)):
    b = weather[weather["날짜"] == str(a.loc[idx, "발생년월일"])]
    a.iloc[idx, 56] = b.iloc[0, 2]
    a.iloc[idx, 57] = b.iloc[0, 3]
    a.iloc[idx, 58] = b.iloc[0, 4]
    a.iloc[idx, 59] = b.iloc[0, 5]
# Out:
#             날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)  강수량(mm)
# 3556  20190927  108     22.9     19.6     27.0      NaN
#             날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)  강수량(mm)
# 3341  20190224  108      6.3      1.2     13.7      NaN
#             날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)  강수량(mm)
# 3309  20190123  108      2.0     -0.8      7.0      NaN
#             날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)  강수량(mm)
# 3413  20190507  108     15.0      8.4     21.9      NaN
#             날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)  강수량(mm)
# 3413  20190507  108     15.0      8.4     21.9      NaN
#             날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)  강수량(mm)
# 3413  20190507  108     15.0      8.4     21.9      NaN
#             날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)  강수량(mm)
# 3627  20191207  108     -2.4     -5.5      1.2      0.1
#             날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)  강수량(mm)
# 3627  20191207  108     -2.4     -5.5      1.2      0.1
#             날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)  강수량(mm)
# ...

# %%
weather["날짜"]
# Out:
# 0       20100101
# 1       20100102
# 2       20100103
# 3       20100104
# 4       20100105
#           ...
# 3647    20191227
# 3648    20191228
# 3649    20191229
# 3650    20191230
# 3651    20191231
# Name: 날짜, Length: 3652, dtype: object

# %%
a["발생년월일"]
# Out:
# 0      2019092705
# 1      2019022406
# 2      2019012303
# 3      2019050712
# 4      2019050712
#           ...
# 527      20120706
# 528      20120921
# 529      20120921
# 530      20120912
# 531      20120825
# Name: 발생년월일, Length: 532, dtype: int64

# %%
a.iloc[:50, 1]
# Out:
# 0     20190927
# 1     20190224
# 2     20190123
# 3     20190507
# 4     20190507
# 5     20190507
# 6     20191207
# 7     20191207
# 8     20190103
# 9     20190407
# 10    20190504
# 11    20190614
# 12    20190808
# 13    20190401
# 14    20190605
# 15    20190504
# 16    20191216
# 17    20190925
# 18    20191216
# 19    20190407
# 20    20190130
# 21    20190130
# 22    20190504
# 23    20190407
# 24    20190401
# 25    20190407
# 26    20190130
# 27    20190313
# 28    20190501
# 29    20190116
# 30    20190313
# 31    20190304
# 32    20190420
# 33    20190614
# 34    20190313
# 35    20190930
# 36    20190724
# 37    20190911
# 38    20190722
# 39    20191030
# 40    20190729
# 41    20190921
# 42    20190606
# 43    20190505
# 44    20190921
# 45    20190606
# 46    20190505
# 47    20190619
# 48    20190125
# 49    20191012
# Name: 발생년월일, dtype: object

# %%
for idx in range(50):
    a.loc[idx, "발생년월일"] = str(a.loc[idx, "발생년월일"])[:8]

# %%
a.to_csv("./qgis_data/cctv_여부_데이터_중복제거.csv", encoding = "euc-kr", index = False)

# %%
a = a.drop_duplicates(["발생년월일", "주야"])
